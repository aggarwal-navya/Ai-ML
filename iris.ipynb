# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('iris_collection.csv')
df.head()
# Out:
#    age    bmi  children smoker   charges     species
# 0   49  24.71         0    yes   8260.00   virginica
# 1   18  20.76         4    yes  10244.42  versicolor
# 2   37  25.70         1     no   5983.10   virginica
# 3   45  24.66         3     no   7572.28   virginica
# 4   61  23.40         2    yes  10442.33      setosa

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1000.000000  1000.000000  1000.000000   1000.000000
# mean     40.215000    24.147220     2.021000   7514.559240
# std      13.332311     4.030443     1.411578   1706.665508
# min      18.000000    10.970000     0.000000   3694.900000
# 25%      29.000000    21.375000     1.000000   6239.797500
# 50%      40.000000    24.075000     2.000000   7297.940000
# 75%      51.250000    26.955000     3.000000   8590.840000
# max      64.000000    37.910000     4.000000  12428.890000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1000 non-null   int64
#  1   bmi       1000 non-null   float64
#  2   children  1000 non-null   int64
#  3   smoker    1000 non-null   object
#  4   charges   1000 non-null   float64
#  5   species   1000 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 47.0+ KB

# %%
df.age.describe()
# Out:
# count    1000.000000
# mean       40.215000
# std        13.332311
# min        18.000000
# 25%        29.000000
# 50%        40.000000
# 75%        51.250000
# max        64.000000
# Name: age, dtype: float64

# %%
fig= plt.hist(df.age, bins=30, color='skyblue', edgecolor='black')

# %%
fig= plt.hist(df.bmi, bins=30, color='lightgreen', edgecolor='black')

# %%
fig= plt.hist(df.charges, bins=30, color='salmon', edgecolor='black')

# %%
fig= plt.scatter(df.bmi, df.charges,alpha=0.5, color='purple', edgecolor='black')

# %%
df.smoker.value_counts()
# Out:
# smoker
# no     708
# yes    292
# Name: count, dtype: int64

# %%
fig = plt.bar(['Smoker','Non-Smoker'],
              [df[df.smoker=='yes'].shape[0],
               df[df.smoker=='no'].shape[0]],
              color=['red','green'],
              edgecolor='black',
              alpha=0.7)

# %%
fig= sns.scatterplot(x='age', y='charges', hue='smoker', data=df, palette=['green','red'], alpha=0.7, edgecolor='black')

# %%
fig= sns.scatterplot(x='bmi', y='charges', hue='smoker', data=df, alpha=0.7, edgecolor='black')

# %%
df.charges.corr(df.age)
# Out:
# np.float64(0.23805848980977307)

# %%
df.charges.corr(df.bmi)
# Out:
# np.float64(0.21927113487698513)

# %%
smoker_valuees= {'no':0, 'yes':1}
smoker_numeric= df.smoker.map(smoker_valuees)
smoker_numeric
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 995    0
# 996    1
# 997    0
# 998    1
# 999    0
# Name: smoker, Length: 1000, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                age       bmi  children   charges
# age       1.000000 -0.023746  0.012100  0.238058
# bmi      -0.023746  1.000000  0.016748  0.219271
# children  0.012100  0.016748  1.000000  0.372311
# charges   0.238058  0.219271  0.372311  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), cmap='Reds', annot=True)
# Out:
# <Axes: >

# %%
def estimate_charges(age, w, b):
    return w*age + b

# %%
w=50
b=100

# %%
estimate_charges(30, w, b)
# Out:
# 1600

# %%
non_smoker_df = df[df.smoker == 'no']
ages= non_smoker_df.age
ages
# Out:
# 2      37
# 3      45
# 6      29
# 7      35
# 9      22
#        ..
# 993    57
# 994    49
# 995    53
# 997    39
# 999    54
# Name: age, Length: 708, dtype: int64

# %%
estimated_charges= estimate_charges(ages, w, b)
estimated_charges
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 estimated_charges= estimate_charges(ages, w, b)
#       2 estimated_charges
#
# TypeError: 'Series' object is not callable
